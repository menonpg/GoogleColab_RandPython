# %%
# Lets upload a data file
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-50baba93-a9e4-43e5-8ed1-cd7cbe0bc9b7" name="files[]" multiple disabled />
#      <output id="result-50baba93-a9e4-43e5-8ed1-cd7cbe0bc9b7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving yahoo_close.csv to yahoo_close.csv

# %%
# Read the content of the uploaded file to a VARIABLE called myData 
import pandas as pd
myData = pd.read_csv('yahoo_close.csv')

# %%
myData.head()
# Out:
#    year month  week  monthweek weekday  VIX.Close
# 0  2012   Jan     1          1     Tue  22.969999
# 1  2012   Jan     1          1     Wed  22.219999
# 2  2012   Jan     1          1     Thu  21.480000
# 3  2012   Jan     1          1     Fri  20.629999
# 4  2012   Jan     2          2     Mon  21.070000

# %%
# Hypothesis statement:  The mean of VIX.Close is the same for all weekdays
import seaborn as sns; sns.set()
ax = sns.boxplot(x="weekday", y="VIX.Close", data=myData)

# %%
# Hypothesis statement:  The mean of VIX.Close is the same for all weekdays
import seaborn as sns; sns.set()
ax = sns.boxplot(x="month", y="VIX.Close", data=myData)

# %%
# Hypothesis statement:  The mean of VIX.Close is the same for all weekdays
import seaborn as sns; sns.set()
ax = sns.boxplot(x="monthweek", y="VIX.Close", data=myData)

# %%
# !pip install mpld3
# Out:
# ...
#      |████████████████████████████████| 798kB 2.8MB/s
# ...
#   Stored in directory: /root/.cache/pip/wheels/c0/47/fb/8a64f89aecfe0059830479308ad42d62e898a3e3cefdf6ba28
# Successfully built mpld3
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

import mpld3
mpld3.enable_notebook()

plt.plot(myData['VIX.Close'])

# %%
import seaborn as sns
sns.set(style="whitegrid")
ax = sns.barplot(x="month", y="VIX.Close", data=myData)

# %%
ax = sns.countplot(x="month", data=myData)
